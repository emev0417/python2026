# %% [markdown]
# Crear un programa en python donde el usuario ingrese dos numeros enteros por teclado verificar cual de los dos numero es mayor

# %%
valor= int(input("Inserte un valor:"))
valor1= input("Inserte un valor:")
print(valor , '<', valor1 , ' es ', valor > valor1)
# Out:
# Inserte un valor: 7
# Inserte un valor: 5
# 7 < 5  es  True

# %% [markdown]
# Ingresar por teclado  la fecha actual: dia,mes y año tambien ingresar la fecha de nacimiento de una persona y calcular cuantos años tiene en años, meses y días

# %%
dia= int(input("Inserte que dia es hoy:"))
mes= int(input("Inserte que mes es hoy en numeros:"))
año= int(input("Inserte que año es hoy:"))
dia1= int(input("Inserte su dia de nacimiento :"))
mes1= int(input("Inserte su mes de nacimiento en numeros :"))
año1= int(input("Inserte su año de nacimiento :"))


print(año-año1,'años',((mes-mes1)+12), 'meses', ((dia-dia1)+31), 'dias')
# Out:
# Inserte que dia es hoy: 12
# Inserte que mes es hoy en numeros: 1
# Inserte que año es hoy: 2026
# Inserte su dia de nacimiento : 17
# Inserte su mes de nacimiento en numeros : 4
# Inserte su año de nacimiento : 2003
# 23 años 9 meses 26 dias

# %% [markdown]
# Elaborar un programa en python que permite ingresar el radio y la altura de un cilindro y calcular el volumen del cilindro sabiendo que la formula es pir2h

# %%
radio=int(input("Ingresar el radio del cilindro")
altura=int(input("Ingresar la altura del cilindro")
print(((radio**2)*altura

# %% [markdown]
# Elaborar un programa que permita convertir una distancia meida en metros a centimetros, milímetros y kilómetros. El usuario debe ingresar el valor en metros y el programa debe mostrar las tres equivalencias correspondientes.
