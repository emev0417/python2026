# %% [markdown]
# ## Introducción a Python <br>
# Python es un lenguaje de **Programación**  de alto nivel enfocado en la inteligencia artificial. <br>
# También me permite generar aplicaciones de escritorio, web, móviles con programación orientada a objetos. <br>
# **Programador** Evelyn Lascano

# %%
#Aqui se escribe un comentario de una sola linea
print("Hola esto es un mensaje")
# Out:
# Hola esto es un mensaje

# %%
print ("Emy Lascano y Nicole Romero")
# Out:
# Emy Lascano y Nicole Romero
