# %%
 # Creación aleatoria de datos
import numpy as np
import random
random.seed(42)

# %%
# crea una nueva variable de lista vacia 
nivel_estudios = []
#creando o ingresando a mi lista varable secundaria  y creo 110 veces secuandaria
#va sumando es decir 172 mas 110 mas 145 y asi se imprime en cualquier orden
nivel_estudios.extend(['Secundaria']*110)
nivel_estudios.extend(['Bachillerato']*172)
nivel_estudios.extend(['Grado']*145)
nivel_estudios.extend(['Master']*52)
nivel_estudios.extend(['Doctorado']*21)
nivel_estudios = np.random.permutation(nivel_estudios)

# %%
print(nivel_estudios)
# Out:
# ['Secundaria' 'Bachillerato' 'Bachillerato' 'Bachillerato' 'Grado'
#  'Master' 'Grado' 'Doctorado' 'Bachillerato' 'Bachillerato' 'Bachillerato'
#  'Bachillerato' 'Bachillerato' 'Bachillerato' 'Secundaria' 'Secundaria'
#  'Grado' 'Secundaria' 'Doctorado' 'Doctorado' 'Grado' 'Bachillerato'
#  'Secundaria' 'Bachillerato' 'Grado' 'Bachillerato' 'Bachillerato'
#  'Bachillerato' 'Master' 'Master' 'Grado' 'Master' 'Bachillerato' 'Master'
#  'Bachillerato' 'Bachillerato' 'Bachillerato' 'Secundaria' 'Master'
#  'Master' 'Secundaria' 'Bachillerato' 'Secundaria' 'Bachillerato' 'Grado'
#  'Secundaria' 'Bachillerato' 'Bachillerato' 'Grado' 'Bachillerato'
#  'Bachillerato' 'Bachillerato' 'Grado' 'Secundaria' 'Bachillerato' 'Grado'
#  'Grado' 'Bachillerato' 'Bachillerato' 'Secundaria' 'Bachillerato'
#  'Bachillerato' 'Bachillerato' 'Master' 'Bachillerato' 'Bachillerato'
#  'Secundaria' 'Master' 'Grado' 'Grado' 'Grado' 'Grado' 'Secundaria'
#  'Secundaria' 'Grado' 'Bachillerato' 'Secundaria' 'Bachillerato'
#  'Secundaria' 'Bachillerato' 'Grado' 'Master' 'Bachillerato' 'Master'
#  'Bachillerato' 'Grado' 'Grado' 'Bachillerato' 'Grado' 'Doctorado' 'Grado'
#  'Grado' 'Master' 'Grado' 'Bachillerato' 'Grado' 'Bachillerato'
#  'Secundaria' 'Doctorado' 'Master' 'Secundaria' 'Grado' 'Master' 'Grado'
#  'Bachillerato' 'Bachillerato' 'Bachillerato' 'Grado' 'Master'
#  'Bachillerato' 'Grado' 'Bachillerato' 'Bachillerato' 'Grado'
#  'Bachillerato' 'Bachillerato' 'Secundaria' 'Grado' 'Grado' 'Secundaria'
#  'Bachillerato' 'Bachillerato' 'Grado' 'Secundaria' 'Master' 'Grado'
#  'Grado' 'Bachillerato' 'Secundaria' 'Secundaria' 'Grado' 'Master'
#  'Bachillerato' 'Grado' 'Bachillerato' 'Grado' 'Grado' 'Grado' 'Master'
#  'Secundaria' 'Bachillerato' 'Bachillerato' 'Grado' 'Secundaria'
#  'Secundaria' 'Secundaria' 'Bachillerato' 'Grado' 'Secundaria'
#  'Bachillerato' 'Secundaria' 'Secundaria' 'Secundaria' 'Bachillerato'
#  'Grado' 'Grado' 'Bachillerato' 'Grado' 'Secundaria' 'Secundaria' 'Master'
#  'Secundaria' 'Bachillerato' 'Bachillerato' 'Secundaria' 'Grado' 'Master'
#  'Grado' 'Grado' 'Bachillerato' 'Grado' 'Secundaria' 'Secundaria'
#  'Bachillerato' 'Grado' 'Doctorado' 'Bachillerato' 'Bachillerato'
#  'Secundaria' 'Secundaria' 'Grado' 'Secundaria' 'Grado' 'Grado' 'Grado'
#  'Secundaria' 'Bachillerato' 'Secundaria' 'Doctorado' 'Grado'
#  'Bachillerato' 'Bachillerato' 'Secundaria' 'Secundaria' 'Secundaria'
#  'Doctorado' 'Secundaria' 'Master' 'Bachillerato' 'Grado' 'Grado' 'Grado'
#  'Secundaria' 'Secundaria' 'Bachillerato' 'Master' 'Grado' 'Grado'
#  'Bachillerato' 'Grado' 'Grado' 'Grado' 'Grado' 'Grado' 'Grado'
#  'Secundaria' 'Doctorado' 'Grado' 'Bachillerato' 'Doctorado' 'Grado'
#  'Bachillerato' 'Grado' 'Grado' 'Bachillerato' 'Secundaria' 'Grado'
#  'Grado' 'Grado' 'Bachillerato' 'Grado' 'Grado' 'Bachillerato'
#  'Bachillerato' 'Grado' 'Grado' 'Grado' 'Grado' 'Secundaria'
#  'Bachillerato' 'Bachillerato' 'Grado' 'Master' 'Secundaria' 'Grado'
#  'Secundaria' 'Bachillerato' 'Secundaria' 'Grado' 'Master' 'Bachillerato'
#  'Grado' 'Bachillerato' 'Grado' 'Grado' 'Grado' 'Secundaria' 'Grado'
#  'Bachillerato' 'Grado' 'Grado' 'Grado' 'Secundaria' 'Bachillerato'
#  'Secundaria' 'Grado' 'Secundaria' 'Doctorado' 'Grado' 'Grado'
#  'Bachillerato' 'Bachillerato' 'Bachillerato' 'Secundaria' 'Bachillerato'
#  'Grado' 'Grado' 'Secundaria' 'Bachillerato' 'Secundaria' 'Bachillerato'
#  'Master' 'Secundaria' 'Master' 'Secundaria' 'Bachillerato' 'Bachillerato'
#  'Secundaria' 'Grado' 'Grado' 'Secundaria' 'Bachillerato' 'Grado' 'Master'
#  'Grado' 'Grado' 'Bachillerato' 'Secundaria' 'Grado' 'Secundaria'
#  'Bachillerato' 'Bachillerato' 'Master' 'Bachillerato' 'Bachillerato'
#  'Grado' 'Master' 'Bachillerato' 'Bachillerato' 'Bachillerato'
#  'Secundaria' 'Doctorado' 'Bachillerato' 'Master' 'Grado' 'Secundaria'
#  'Master' 'Bachillerato' 'Secundaria' 'Master' 'Bachillerato'
#  'Bachillerato' 'Doctorado' 'Secundaria' 'Secundaria' 'Grado' 'Grado'
#  'Bachillerato' 'Master' 'Secundaria' 'Bachillerato' 'Bachillerato'
#  'Master' 'Grado' 'Bachillerato' 'Grado' 'Bachillerato' 'Master'
#  'Bachillerato' 'Secundaria' 'Grado' 'Bachillerato' 'Master'
#  'Bachillerato' 'Bachillerato' 'Doctorado' 'Grado' 'Secundaria' 'Grado'
#  'Grado' 'Master' 'Bachillerato' 'Bachillerato' 'Master' 'Bachillerato'
#  'Secundaria' 'Secundaria' 'Secundaria' 'Bachillerato' 'Master'
#  'Bachillerato' 'Secundaria' 'Bachillerato' 'Grado' 'Master' 'Master'
#  'Bachillerato' 'Master' 'Secundaria' 'Bachillerato' 'Bachillerato'
#  'Bachillerato' 'Grado' 'Secundaria' 'Grado' 'Grado' 'Grado'
#  'Bachillerato' 'Grado' 'Grado' 'Bachillerato' 'Grado' 'Master'
#  'Secundaria' 'Bachillerato' 'Secundaria' 'Bachillerato' 'Grado'
#  'Bachillerato' 'Bachillerato' 'Secundaria' 'Grado' 'Grado' 'Doctorado'
#  'Bachillerato' 'Bachillerato' 'Bachillerato' 'Master' 'Bachillerato'
#  'Bachillerato' 'Grado' 'Bachillerato' 'Doctorado' 'Grado' 'Secundaria'
#  'Secundaria' 'Secundaria' 'Secundaria' 'Bachillerato' 'Grado'
#  'Secundaria' 'Secundaria' 'Bachillerato' 'Secundaria' 'Bachillerato'
#  'Grado' 'Grado' 'Grado' 'Master' 'Secundaria' 'Grado' 'Master'
#  'Secundaria' 'Bachillerato' 'Bachillerato' 'Bachillerato' 'Secundaria'
#  'Secundaria' 'Grado' 'Secundaria' 'Doctorado' 'Bachillerato' 'Grado'
#  'Bachillerato' 'Master' 'Bachillerato' 'Bachillerato' 'Grado'
#  'Bachillerato' 'Bachillerato' 'Master' 'Master' 'Secundaria'
#  'Bachillerato' 'Secundaria' 'Grado' 'Doctorado' 'Secundaria'
#  'Bachillerato' 'Bachillerato' 'Secundaria' 'Grado' 'Bachillerato'
#  'Secundaria' 'Bachillerato' 'Bachillerato' 'Bachillerato' 'Bachillerato'
#  'Bachillerato' 'Grado' 'Bachillerato' 'Grado' 'Secundaria' 'Doctorado'
#  'Bachillerato' 'Grado' 'Bachillerato' 'Master' 'Secundaria' 'Doctorado'
#  'Master' 'Secundaria' 'Doctorado' 'Secundaria' 'Grado' 'Secundaria'
#  'Bachillerato' 'Grado' 'Bachillerato' 'Master' 'Bachillerato'
#  'Secundaria' 'Secundaria' 'Bachillerato' 'Secundaria' 'Bachillerato'
#  'Bachillerato' 'Bachillerato' 'Grado' 'Grado' 'Secundaria' 'Bachillerato'
#  'Grado' 'Grado' 'Bachillerato' 'Grado' 'Grado' 'Grado' 'Bachillerato'
#  'Bachillerato']

# %%
# DIAGRAMA DE BARRAS
import matplotlib.pyplot as plt
import numpy as np
estudios, frecuencia = np.unique(nivel_estudios, return_counts=True)
print(estudios, frecuencia)
# Out:
# ['Bachillerato' 'Doctorado' 'Grado' 'Master' 'Secundaria'] [172  21 145  52 110]

# %%
plt.ylabel('Frecuencia absoluta')
plt.xlabel('Nivel de estudios')
plt.title('Diagrama de barras')
plt.bar(estudios, frecuencia) # https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.bar.html
plt.show()

# %%
 # DIAGRAMA DE SECTORES
colores = {'red', 'blue', 'orange', 'green', 'cyan'}
plt.pie(frecuencia, labels=estudios, colors=colores, autopct='%1.2f%%')
plt.title('Diagrama de sectores')
plt.show()

# %%
#tarea implementar con pandas esta infromacion esta en matrises ahora quiero en data frame
import pandas as pd
df=pd.DataFrame(nivel_estudios)
# Out:
#   Cell In[10], line 4
#     colums=¨
#            ^
# SyntaxError: invalid character '¨' (U+00A8)
