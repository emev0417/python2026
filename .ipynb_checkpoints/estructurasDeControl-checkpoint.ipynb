# %% [markdown]
# # TERCER MODULO - Python , Estructuras de Control
# <img src="img/Logo.jpeg" alt="logo itq" width="200">
#
# **Nombre:** *Evelyn Lascano*<br>
# **Fecha:** *19/01/2026*

# %% [markdown]
# ## 1 Estructuras de control
# 1.1 Selección (sentencias condicionales)
# * Selección de una de varias alternativas en base a alguna condición.
# * Indentación para estructurar el código
# * Importante el símbolo ‘:’

# %%
# Asigno el bvalo uno a la variable x
x = int(input("Ingrese el valor de x"))
#Implemento una condicional para saber si x es mayor a 0
if x > 0:
    print('Valor positivo')
else:
    print('Valor no positivo')
# Out:
# Ingrese el valor de x 5
# Valor positivo

# %% [markdown]
# * Las condiciones son expresiones que se evalúan a True o False.
# * Operadores de comparación, lógicos, de identidad y de pertenencia vistos anteriormente.

# %%
x = 3
y = [1, 2, 3]
print(x > 0)
print(x > 0 and x < 10)
print(x is not y)
print(x in y)
# Out:
# True
# True
# True
# True

# %% [markdown]
# * Se pueden introducir más ‘ramas’ en sentencias condicionales a través de la palabra clave elif.

# %%
x = -3
if x > 0:
    print('Valor positivo')
elif x == 0:
    print('Valor nulo')
else:
    print('Valor negativo')
# Out:
# Valor negativo

# %% [markdown]
# * Anidamiento.

# %%
val = 120
if val > 0:
    if val < 100:
        print('Valor positivo')
    else:
        print('Valor muy positivo')
else:
    print('Valor negativo')
# Out:
# Valor muy positivo

# %% [markdown]
# ### Ejercicios

# %% [markdown]
# 1. Ingresar dos valores enteros por teclado y muestre por pantalla su división si el divisor es cero el programa debe mostrar un mensaje de error.

# %%
#Utilizo float ya que la division puede o no ser exacta y la respuesta seria con decimales.
x=float(input("Ingrese el dividendo:"))
y=float(input('Ingrese el "divisor:'))

#Uso if para que si "y" es igual 0 de error 
if y==0:
     print('División para cero no existe')
    
#De lo contrario realiza normalmente la división
else:
    print('El resultado de la división es:', x/y)
# Out:
# Ingrese el dividendo: 6
# Ingrese el "divisor: 2
# El resultado de la división es: 3.0

# %% [markdown]
# ![image.png](attachment:3473cdc6-c05a-4232-88bb-43010329a57c.png)

# %% [markdown]
# 2. Escribir un programa en python que pida al usuario un número entero por teclado y muestre en pantalla si es par o impar.

# %%
#Con la función int hacemos que lo que ingrese a input cambie de tipo de string a entero.
numero=int(input("Ingrese un número entero: "))

#Aqui el if verifica si el numero ingresado tiene residuo es impar sino es par.
if numero % 2==0: 
    print("El número es par")
else:
    print("El número es impar")

# %% [markdown]
# ![image.png](attachment:f1222191-1d66-4c31-8b24-42bbfaa0db21.png)

# %% [markdown]
# 3. Escribir un programa en python para una empresa que tiene salas de juego para todas las edades y quiere calcular de forma automática el precio que debe cobrar a sus clientes por entrada.El programa debe preguntar al usuario: el nombre y la edad del cliente y mostrar el precio de entrada si el cliente es menor de 4 años puede ingresar gratis, si tiene entre 4 y 18 años debe pagar 5 dólares y si es mayor de 18 años 10  dólares.

# %%
name = input("Ingrese su nombre:")

#Convertimos la funcion input en entero con int
age = (int(input("Ingrese su edad:")))

#Aqui el if verifica si el numero ingresado es menor a 4
if age<4:
    print('Su entrada es gratuita')

#Aqui el elif verifica si el numero ingresado es mayor igual 4 y menor que 18
elif age>=4 and age<=18:
    print('El valor de su entrada es 5$')

#De lo contrario el numero es mayor de 18
else:
    print('El valor de su entrada es 10')
# Out:
# Ingrese su nombre Emy
# Ingrese su edad 18
# El valor de su entrada es 5$

# %% [markdown]
# ![image.png](attachment:8f92be90-c588-4055-bd89-615f762ce826.png)

# %% [markdown]
# 4. Para atributar un determinado impuesto se debe ser mayor de 16 años y tener unos ingresos iguales o superirores a 1000$ mensuales, escribir un programa que pregunte al usuario su edad y sus ingresos mensalues
# y muestre por pantalla si el usuario tiene que tributar o no.

# %%
#Con la función int hacemos que lo que ingrese a input cambie de tipo de string a entero
age = (int(input("Ingrese su edad:")))
bills = (int(input("¿Cuáles son sus ingresos mensuales?:")))

#Aqui el if verifica que edad sea mayor a 16 y bills sea >1000 dolares para que el usuario tenga o no que tributar
if age>16 and bills>=1000:
    print('Usted deber tributar')
else:
    print('Usted no debe tributar')
# Out:
# Ingrese su edad: 17
# ¿Cuáles son sus ingresos mensuales?: 1000
# Usted deber tributar

# %% [markdown]
# ![image.png](attachment:9f7a108e-1f79-42ea-8159-b51c88eec232.png)

# %% [markdown]
# 2. Switch

# %%
a =-6
match a:
    case _ if a > 0:
        print('positive')
    case _ if a == 0:
        print('zero')
    case _ if a < 0:
        print('negative')
# Out:
# negative

# %%
a = 'l' #week day
match a:
    case 'L':
        print("Lunes")
    case 'M':
        print("Martes")
    case 'X':
        print("Miercoles")
    case _:
        print("Wrong Day")
# Out:
# Wrong Day

# %% [markdown]
# ### Expresión ternaria
# * Estructura if-else condensado en una línea.
# * Se recomienda usar solo en casos sencillos.

# %%
#Ejemplo: cálculo del valor absoluto de un número.
x =-3
#Operacion ternaria
resultado = x if x >= 0 else-x
print(resultado)
# Out:
# 3

# %%
val =-3
if val >=0:
    resultado = val
else:
    resultado =-val
print(resultado)
# Out:
# 3

# %% [markdown]
# ### Concatenación de comparaciones
# * Se pueden concatenar comparaciones en una misma expresión:– and: true, si ambos son true.– or: true, si al menos uno es true.– not: inversión del valor de verdad de una expresión.
# * ‘elif’ para comparar tras un ‘if’
# Enlace a Tablas de Verdad.

# %%
genero = 'Drama'
fecha_de_estreno = 1989
if genero == 'Comedia' or genero == 'Acción':
    print('Buena película!')
elif fecha_de_estreno >= 1990 and fecha_de_estreno < 2000:
     print('Buena década!')
else:
    print('Meh')
# Out:
# Meh

# %% [markdown]
# ###Comparación de variables: ‘==’ vs ‘is’
# * ‘==’ compara si el valor de las variables es el mismo
# * ‘is’ compara si los objetos en las variables son iguales (referencia)

# %%
a = 1000
b = a
print(a is b)
print(a == b)

c=type(a)
print(c)
d=type(b)
print(d)

print(c==d)

print(id(a))
print(id(b))
# Out:
# True
# True
# <class 'int'>
# <class 'int'>
# True
# 2297295544080
# 2297295544080

# %%
a = [1, 2, 3]
b = [1, 2, 3]
c = a

print(a is b)
print(a is c)
print(a == b)

print(id(a))
print(id(b))
print(id(c))
# Out:
# False
# True
# True
# 2297297140864
# 2297297207680
# 2297297140864

# %% [markdown]
# ### Valor booleano
# * Todos los objetos en Python tiene inherentemente un valor booleano: True o False.
# * Cualquier número distinto de 0 ó cualquier objeto no vacío tienen valor True.
# * El número 0, objetos vacíos y el objeto especial None tienen valor False.

# %%
a =-10 #True
b = None #False
if a:
    print("a es True")
if not b:
    print("b es False")
# Out:
# a es True
# b es False

# %%
c = [1,2,3]
# a c le reasigno None
c = None #0 es igual a vacio a nada
if c:
    print("Lista no vacía")
else:
    print("Lista vacía")
# Out:
# Lista vacía

# %% [markdown]
# ### Ejercicios

# %% [markdown]
# 1. Escribir un programa en python  donde el usuario ingrese por teclado el nombre de la operacion suma,resta,multuplicación o división también el usuario debera ingresar dos números de cualquier tipo mediate un switch comparar que operación ingresa y mostrar en pantalla el resultado. (

# %%
#Utilizamos la funcion input para ingresa 
operacion=input('Ingrese que operación quiere realizar:')

#Utilizamos float para que los numero puedan ser decimales también.
x=float(input('Ingrese un número'))
y=float(input('Ingrese un número'))

#Usamos match para que pueda revisar las opciones y elija la que el usuario ingrese por pantalla caso contrario dara un mensaje de que esa operacio no existe
match operacion:
    case 'suma':
        print(x+y)
    case 'resta':
        print(x-y)
    case 'division':
        
#Usamos if en la division ya que debe revisar que la / para 9 no existe
        if y==0:
            print('La división para cero no existe')

#Si no hay  problema en el if realiza la operación
        else:
            print (x/y)
    case 'multiplicacion':
        print(x*y)
    case _:
        print('No existe la operación')
# Out:
# Ingrese que operación quiere realizar: 9
# Ingrese un número 9
# Ingrese un número 0
# No existe la operacion

# %% [markdown]
# 2. Desarrollar un programa en python  donde se resuelva una ecuación de segundo grado mediante la fórmula general, el usuario debe ingresar por teclado los valores a,b y c y mostrar en pantalla los valores de la ecuación.

# %%
#Importamos la libreria math para poder resolver la raiz.
import math

#Utilizamos float para que los numero puedan ser decimales también
a=float(input('Ingrese el valor de a:'))
b=float(input('Ingrese el valor de b:'))
c=float(input('Ingrese el valor de c:'))

#Aqui se realizan la operacion que son criticas y que podrian hacer que la ecuacion no tenga solución.
raiz=(b**2)-4*a*c
denominador=2*a

#Aqui con el if revisa si la raiz es <0 ya que no se puede realizar por ra´ces imaginarias.
if raiz <0:
    print('No existe solucion para raices imaginarias')

#El else realiza la operación si no hay problema o un número negativo.
else:
    resultado_raiz= math.sqrt(raiz)

#Utilizo if para el denominador ya que no existe la division para cero
    if denominador==0:
        print('La division para cero no existe')

#Con else si no hay niguna limitación antes procede a realizar la operación e imprime el valor de x positivo y negativo.
    else:
        x1=(-b+resultado_raiz)/denominador
        x2=(-b-resultado_raiz)/denominador
        print('x1=',x1)
        print('x2=',x2)
# Out:
# Ingrese el valor de a: 1
# Ingrese el valor de b: 3
# Ingrese el valor de c: 1
# x1= -0.3819660112501051
# x2= -2.618033988749895

# %% [markdown]
# ## 3 Iteración (bucles)
# * Repetición de un bloque de código.
# * La terminación del bucle depende del tipo de bucle.
# * Dos tipos: while y for.
# ### Bucle ‘while’
# * Repetición de un bloque de código hasta que se deje cumplir una expresión (es decir, hasta
# que una condición evalue a False).
# * Si la condición evalua a False desde el principio, el bloque de código nunca se ejecuta.
# * Cuidado con los bucles infinitos.<br>
# Formato general:<br>
# `while test: Mientras se cumple la condición `<br>
# `statements Instrucciones a ejecutar `

# %%
# Ejemplo: Mostrar los primeros 3 objetos de una lista
#Contador - El contador cuenta la veces que se ha repetido el codigo
#Acumulador - Acula los valores de la repeticón y al final esos valores se suman
indice = 0
numeros = [9, 4, 7, 1, 2]

while indice < 3:
    print(numeros[indice])
    
    indice =indice+1

# %%
# Ejemplo: contar y mostrar los números inferiores a 10.
numeros = [33, 3, 9, 21, 1, 7, 12, 10, 8]
contador = 0
indice = 0
while indice < len(numeros):
    if numeros[indice] < 10:
    print(numeros[indice])
contador += 1
indice += 1
print('Contador:', contador)
print('Indice:', indice)

# %%
nombre = 'Pablo'
while nombre: # Mientras 'nombre' no sea vacío
    
    print(nombre)
nombre = nombre[1:]

# %% [markdown]
# https://github.com/emev0417/python2026/blob/main/estructurasDeControl.ipynb
