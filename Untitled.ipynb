# %%
letras = ['a', 'b', 'c', 'd', 1]
print(len(letras))
# Out:
# 5

# %%
print(letras[2])
print(letras[-4])
print(letras[0])
# Out:
# c
# b
# a

# %%
letras = ['a', 'b', 'c', 'f', 'g', 'h', 'i', 'j', 'k']
print(id(letras))
# Out:
# 3077166815488

# %%
letras[0:7:2] = ['z', 'x', 'y','p']
print(letras)
# print(id(letras))
# Out:
# ['z', 'b', 'x', 'f', 'y', 'h', 'p', 'j', 'k']
